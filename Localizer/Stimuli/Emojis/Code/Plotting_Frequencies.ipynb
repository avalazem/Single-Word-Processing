# %%
import pandas as pd
emoji_df = pd.read_csv(r"C:\Users\ali_a\Desktop\Single_Word_Processing_Stage\Single_Word_Processing\Localizer\Stimuli\Emojis\frequencies_w_emoji.txt", sep='\t', header=None)

# %%
import seaborn as sns

# %%
emoji_df.columns = ['Emoji', 'Frequency']

# %%
print(emoji_df.head())
# Out:
#   Emoji   Frequency
# 0     😂  1357923415
# 1     ♥   611163235
# 2     ❤   606282827
# 3     😍   529915039
# 4     😭   392089577

# %%
sns.histplot(emoji_df)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.histplot(emoji_df, x='Emoji', y='Frequency')
# Out:
# <Axes: xlabel='Emoji', ylabel='Frequency'>
# c:\Users\ali_a\Desktop\Single_Word_Processing_Stage\Single_Word_Processing\.venv\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 128514 (\N{FACE WITH TEARS OF JOY}) missing from font(s) Verdana.
#   func(*args, **kwargs)
# c:\Users\ali_a\Desktop\Single_Word_Processing_Stage\Single_Word_Processing\.venv\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 9829 (\N{BLACK HEART SUIT}) missing from font(s) Verdana.
#   func(*args, **kwargs)
# c:\Users\ali_a\Desktop\Single_Word_Processing_Stage\Single_Word_Processing\.venv\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 10084 (\N{HEAVY BLACK HEART}) missing from font(s) Verdana.
#   func(*args, **kwargs)
# c:\Users\ali_a\Desktop\Single_Word_Processing_Stage\Single_Word_Processing\.venv\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 128525 (\N{SMILING FACE WITH HEART-SHAPED EYES}) missing from font(s) Verdana.
#   func(*args, **kwargs)
# ...

# %%
sns.histplot(emoji_df['Frequency'], bins=30)
# Out:
# <Axes: xlabel='Frequency', ylabel='Count'>

# %%
import matplotlib.pyplot as plt

# %%
sns.histplot(emoji_df['Frequency'], bins=30)
plt.title('Emoji Frequency Distribution 📊')
plt.show()
# Out:
# c:\Users\ali_a\Desktop\Single_Word_Processing_Stage\Single_Word_Processing\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) Verdana.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
from matplotlib.font_manager import FontProperties

# %%
font_properties = FontProperties(family='Segoe UI Emoji')

# %%
# Plotting the data
sns.histplot(emoji_df, log_scale=True)
font_properties = FontProperties(family='Segoe UI Emoji')

# Customizing the legend with emojis
plt.legend(['Emoji 😊', 'Emoji 🚀'], prop=font_properties)

# Adding a title to the plot
plt.title('Emoji Frequency Distribution 📊', fontproperties=font_properties)

# Display the plot
plt.show()
# Out:
# findfont: Font family ['STIXGeneral'] not found. Falling back to DejaVu Sans.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\ali_a\Desktop\Single_Word_Processing_Stage\Single_Word_Processing\.venv\Lib\site-packages\IPython\core\formatters.py:402, in BaseFormatter.__call__(self, obj)
#     400     pass
#     401 else:
# --> 402     return printer(obj)
#     403 # Finally look for special method names
#     404 method = get_real_method(obj, self.print_method)
#
# File c:\Users\ali_a\Desktop\Single_Word_Processing_Stage\Single_Word_Processing\.venv\Lib\site-packages\IPython\core\pylabtools.py:170, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     167     from matplotlib.backend_bases import FigureCanvasBase
#     168     FigureCanvasBase(fig)
# --> 170 fig.canvas.print_figure(bytes_io, **kw)
#     171 data = bytes_io.getvalue()
# ...

# %%
font_properties = FontProperties(family='Segoe UI Emoji')

# %%
sns.histplot(emoji_df)
# Out:
# <Axes: ylabel='Count'>
# findfont: Font family ['STIXGeneral'] not found. Falling back to DejaVu Sans.
# Error in callback <function _draw_all_if_interactive at 0x000002E790BA1580> (for post_execute), with arguments args (),kwargs {}:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\ali_a\Desktop\Single_Word_Processing_Stage\Single_Word_Processing\.venv\Lib\site-packages\matplotlib\pyplot.py:279, in _draw_all_if_interactive()
#     277 def _draw_all_if_interactive() -> None:
#     278     if matplotlib.is_interactive():
# --> 279         draw_all()
#
# File c:\Users\ali_a\Desktop\Single_Word_Processing_Stage\Single_Word_Processing\.venv\Lib\site-packages\matplotlib\_pylab_helpers.py:131, in Gcf.draw_all(cls, force)
#     129 for manager in cls.get_all_fig_managers():
#     130     if force or manager.canvas.figure.stale:
# ...

# %%
sns.histplot(emoji_df, x='Emoji', y='Frequency')
# Out:
# <Axes: xlabel='Emoji', ylabel='Frequency'>

# %%
import matplotlib.font_manager as fm

for font in fm.findSystemFonts(fontpaths=None, fontext='ttf'):
    if "Segoe" in font:
        print(font)  # Look for "Segoe UI Emoji" or "Noto Color Emoji"
# Out:
# C:\Windows\Fonts\SegoeIcons.ttf

# %%
font_path = r"C:\Windows\Fonts\SEGUIEMJ.TTF"
prop = fm.FontProperties(fname=font_path)

# %%
plt.rcParams['font.family'] = prop.get_name()

# %%
import os
print(os.path.exists(r"C:\Windows\Fonts\SEGUIEMJ.TTF"))
# Out:
# True

# %%
sns.histplot(emoji_df, x='Emoji', y='Frequency', log_scale=True)
plt.title("Emoji Frequency Distribution", fontsize=12, fontproperties=prop)
plt.xticks([])
# Out:
# ([], [])
# findfont: Font family ['STIXGeneral'] not found. Falling back to DejaVu Sans.
# Error in callback <function _draw_all_if_interactive at 0x000002E790BA1580> (for post_execute), with arguments args (),kwargs {}:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\ali_a\Desktop\Single_Word_Processing_Stage\Single_Word_Processing\.venv\Lib\site-packages\matplotlib\pyplot.py:279, in _draw_all_if_interactive()
#     277 def _draw_all_if_interactive() -> None:
#     278     if matplotlib.is_interactive():
# --> 279         draw_all()
#
# File c:\Users\ali_a\Desktop\Single_Word_Processing_Stage\Single_Word_Processing\.venv\Lib\site-packages\matplotlib\_pylab_helpers.py:131, in Gcf.draw_all(cls, force)
#     129 for manager in cls.get_all_fig_managers():
#     130     if force or manager.canvas.figure.stale:
# --> 131         manager.canvas.draw_idle()
#
# ...

# %%
emoji_df['Index'] = range(1, len(emoji_df) + 1)
df_no_emoji = emoji_df.drop(columns=['Emoji'])
plt.figure(figsize=(12, 5))
sns.histplot(data=df_no_emoji, x='Index', y='Frequency')
plt.title("Emoji Frequency Distribution", fontsize=12, fontproperties=prop)
plt.yscale('log') 
plt.xticks([])
plt.show()
# Out:
# findfont: Font family ['STIXGeneral'] not found. Falling back to DejaVu Sans.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\ali_a\Desktop\Single_Word_Processing_Stage\Single_Word_Processing\.venv\Lib\site-packages\IPython\core\formatters.py:402, in BaseFormatter.__call__(self, obj)
#     400     pass
#     401 else:
# --> 402     return printer(obj)
#     403 # Finally look for special method names
#     404 method = get_real_method(obj, self.print_method)
#
# File c:\Users\ali_a\Desktop\Single_Word_Processing_Stage\Single_Word_Processing\.venv\Lib\site-packages\IPython\core\pylabtools.py:170, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     167     from matplotlib.backend_bases import FigureCanvasBase
#     168     FigureCanvasBase(fig)
# --> 170 fig.canvas.print_figure(bytes_io, **kw)
#     171 data = bytes_io.getvalue()
# ...

# %%
font_path = r"C:\Windows\Fonts\SegoeUIEmojiRegular.ttf"

# %%
# Load the font
prop = fm.FontProperties(fname=font_path)
plt.rcParams['font.family'] = prop.get_name()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[46], line 3
#       1 # Load the font
#       2 prop = fm.FontProperties(fname=font_path)
# ----> 3 plt.rcParams['font.family'] = prop.get_name()
#
# File c:\Users\ali_a\Desktop\Single_Word_Processing_Stage\Single_Word_Processing\.venv\Lib\site-packages\matplotlib\font_manager.py:731, in FontProperties.get_name(self)
#     727 def get_name(self):
#     728     """
#     729     Return the name of the font that best matches the font properties.
#     730     """
# --> 731     return get_font(findfont(self)).family_name
#
# File c:\Users\ali_a\Desktop\Single_Word_Processing_Stage\Single_Word_Processing\.venv\Lib\site-packages\matplotlib\font_manager.py:1615, in get_font(font_filepaths, hinting_factor)
#    1612 if hinting_factor is None:
#    1613     hinting_factor = mpl.rcParams['text.hinting_factor']
# ...

# %%
sns.histplot(emoji_df, x='Emoji', y='Frequency')
plt.title("Emoji Frequency Distribution 😀", fontsize=16)
plt.show()
# Out:
# c:\Users\ali_a\Desktop\Single_Word_Processing_Stage\Single_Word_Processing\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128512 (\N{GRINNING FACE}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\ali_a\Desktop\Single_Word_Processing_Stage\Single_Word_Processing\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128514 (\N{FACE WITH TEARS OF JOY}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\ali_a\Desktop\Single_Word_Processing_Stage\Single_Word_Processing\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 10084 (\N{HEAVY BLACK HEART}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\ali_a\Desktop\Single_Word_Processing_Stage\Single_Word_Processing\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128525 (\N{SMILING FACE WITH HEART-SHAPED EYES}) missing from font(s) Arial.
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.font_manager as fm

emoji_df = pd.read_csv(r"C:\Users\ali_a\Desktop\Single_Word_Processing_Stage\Single_Word_Processing\Localizer\Stimuli\Emojis\frequencies_w_emoji.txt", sep='\t', header=None) 
emoji_df.columns = ['Emoji', 'Frequency']
emoji_df['Index'] = range(1, len(emoji_df) + 1)
print(emoji_df.head())
plt.figure(figsize=(12, 5))
sns.histplot(data=emoji_df, x='Index', y='Frequency', log_scale=True)
plt.title("Emoji Frequency Distribution (Log Scale)", fontsize=12)
plt.xlabel('Emoji')
plt.xticks([])
plt.show()
# Out:
#   Emoji   Frequency  Index
# 0     😂  1357923415      1
# 1     ♥   611163235      2
# 2     ❤   606282827      3
# 3     😍   529915039      4
# 4     😭   392089577      5

# %%
# Plotting the data
plt.figure(figsize=(12, 5))
sns.histplot(data=emoji_df, x='Emoji', y='Frequency', log_scale=True)
plt.title("Emoji Frequency Distribution (Log Scale)", fontsize=12)
plt.xlabel('Emoji')

# Setting x-axis ticks to display every 20th emoji
xticks = emoji_df['Emoji'][::20]
plt.xticks(ticks=range(0, len(emoji_df), 20), labels=xticks)

plt.show()
# Out:
# c:\Users\ali_a\Desktop\Single_Word_Processing_Stage\Single_Word_Processing\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128074 (\N{FISTED HAND SIGN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\ali_a\Desktop\Single_Word_Processing_Stage\Single_Word_Processing\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128154 (\N{GREEN HEART}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\ali_a\Desktop\Single_Word_Processing_Stage\Single_Word_Processing\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 127925 (\N{MUSICAL NOTE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\ali_a\Desktop\Single_Word_Processing_Stage\Single_Word_Processing\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128123 (\N{GHOST}) missing from font(s) DejaVu Sans.
# ...

# %%
import math
import pandas as pd
emoji_df = pd.read_csv(r"C:\Users\ali_a\Desktop\Single_Word_Processing_Stage\Single_Word_Processing\Localizer\Stimuli\Emojis\data\frequencies_w_emoji.txt", sep='\t', header=None)
emoji_df.columns = ['Emoji', 'Frequency', 'Log Frequency']
print(emoji_df.head())
emoji_df.to_csv(r"C:\Users\ali_a\Desktop\Single_Word_Processing_Stage\Single_Word_Processing\Localizer\Stimuli\Emojis\data\frequencies_w_emoji.txt")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 4
#       2 import pandas as pd
#       3 emoji_df = pd.read_csv(r"C:\Users\ali_a\Desktop\Single_Word_Processing_Stage\Single_Word_Processing\Localizer\Stimuli\Emojis\data\frequencies_w_emoji.txt", sep='\t', header=None)
# ----> 4 emoji_df.columns = ['Emoji', 'Frequency', 'Log Frequency']
#       5 print(emoji_df.head())
#       6 emoji_df.to_csv(r"C:\Users\ali_a\Desktop\Single_Word_Processing_Stage\Single_Word_Processing\Localizer\Stimuli\Emojis\data\frequencies_w_emoji.txt")
#
# File c:\Users\ali_a\Desktop\Single_Word_Processing_Stage\Single_Word_Processing\.venv\Lib\site-packages\pandas\core\generic.py:6313, in NDFrame.__setattr__(self, name, value)
#    6311 try:
#    6312     object.__getattribute__(self, name)
# -> 6313     return object.__setattr__(self, name, value)
#    6314 except AttributeError:
# ...

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# Load image
img = Image.open("your_image.png").convert("RGB")  # Ensure RGB format

# Convert image to NumPy array
pixels = np.array(img)

# Get individual channels
red_channel = pixels[:, :, 0]
green_channel = pixels[:, :, 1]
blue_channel = pixels[:, :, 2]

# Plot histogram of pixel values
plt.hist(pixels.flatten(), bins=256, color='gray', alpha=0.7)
plt.xlabel("Pixel Intensity")
plt.ylabel("Frequency")
plt.title("Pixel Value Distribution")
plt.show()

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# Load image
img = Image.open(r"C:\Users\ali_a\Desktop\Single_Word_Processing_Stage\Single_Word_Processing\Localizer\Stimuli\Emojis\Emoji Localizer png's\yum_no_mask.png").convert("RGB")  # Ensure RGB format

# Convert image to NumPy array
pixels = np.array(img)

# Get individual channels
red_channel = pixels[:, :, 0]
green_channel = pixels[:, :, 1]
blue_channel = pixels[:, :, 2]

# Plot histogram of pixel values
plt.hist(pixels.flatten(), bins=256, color='gray', alpha=0.7)
plt.xlabel("Pixel Intensity")
plt.ylabel("Frequency")
plt.title("Pixel Value Distribution")
plt.show()

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# Load the grayscale image
img = Image.open(r"C:\Users\ali_a\Desktop\Single_Word_Processing_Stage\Single_Word_Processing\Localizer\Stimuli\Emojis\Emoji Localizer png's\yum_no_mask.png").convert("RGB")  # Ensure RGB format

# Convert image to a NumPy array and flatten it to 1D
pixels = np.array(img).flatten()

# Create a single X-axis value repeated for all pixels
x_axis = np.ones_like(pixels)  # Same length as pixels, but all set to 1

# Scatter plot
plt.figure(figsize=(4, 6))
plt.scatter(x_axis, pixels, color="black", alpha=0.5, s=1)  # Small dots for visibility
plt.ylabel("Pixel Intensity (0-255)")
plt.xticks([])  # Hide X-axis ticks
plt.title("Pixel Intensity Distribution")

plt.show()

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# Load the grayscale image (pixel values already represent luminance)
img = Image.open(r"C:\Users\ali_a\Desktop\Single_Word_Processing_Stage\Single_Word_Processing\Localizer\Stimuli\Emojis\Emoji Localizer png's\yum_no_mask.png").convert("RGB")  # Ensure RGB format

# Convert to a NumPy array and flatten it
luminance_values = np.array(img).flatten()

# Create a single X-axis value repeated for all pixels
x_axis = np.ones_like(luminance_values)  # Same length as pixels, but all set to 1

# Scatter plot
plt.figure(figsize=(4, 6))
plt.scatter(x_axis, luminance_values, color="black", alpha=0.5, s=1)  # Small dots for visibility
plt.ylabel("Luminance (0-255)")
plt.xticks([])  # Hide X-axis ticks
plt.title("Luminance Distribution")

plt.show()

# %%
from PIL import Image
import numpy as np

# Load the image
img = Image.open(r"C:\Users\ali_a\Desktop\Single_Word_Processing_Stage\Single_Word_Processing\Localizer\Stimuli\Emojis\Emoji Localizer png's\yum_no_mask.png").convert("RGB")  # Ensure RGB format
print("Image mode:", img.mode)  # Check if it's 'L', 'RGB', or something else

# Convert to grayscale (if not already)
gray_img = img.convert("L")

# Convert to NumPy array
pixels = np.array(gray_img)

# Print pixel value statistics
print("Min pixel value:", pixels.min())
print("Max pixel value:", pixels.max())
print("Mean pixel value:", pixels.mean())
# Out:
# Image mode: RGB
# Min pixel value: 4
# Max pixel value: 248
# Mean pixel value: 151.07708636836628
